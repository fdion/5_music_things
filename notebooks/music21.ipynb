# %% [markdown]
# # Music21
#
# Music21 is a set of tools for helping scholars and other active listeners answer questions about music quickly and simply.

# %%
from music21 import *

# %%
environment.UserSettings()['lilypondPath']='/Users/francois/bin/lilypond'
environment.set('pdfPath','/Users/francois/bin/musescore')
environment.set('graphicsPath','/Users/francois/bin/musescore')

# %% [markdown]
# ipython magic, this one to handle show() directly

# %%
# %load_ext music21.ipython21

# %%
c = chord.Chord("C4 E4 G4")
c.isConsonant()
# Out:
# True

# %%
c.show()

# %%
# !wget http://www.piano-midi.de/midis/debussy/deb_clai_format0.mid
# Out:
# --2016-09-27 20:09:10--  http://www.piano-midi.de/midis/debussy/deb_clai_format0.mid
# Resolving www.piano-midi.de... 82.165.134.185
# Connecting to www.piano-midi.de|82.165.134.185|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16653 (16K) [audio/midi]
# Saving to: 'deb_clai_format0.mid.1'
#
# deb_clai_format0.mi 100%[=====================>]  16.26K  --.-KB/s   in 0s
#
# 2016-09-27 20:09:11 (39.2 MB/s) - 'deb_clai_format0.mid.1' saved [16653/16653]

# %%
midi_data = converter.parse('deb_clai_format0.mid')

# %%
midi_data.show()

# %%
sp = midi.realtime.StreamPlayer(midi_data)
sp.play()
